# %% [markdown]
# <h1>CS689A: Computational Linguistics for Indian Languages</h1>
# <h2>Assignment-2</h2>
# <h3>Question-2</h3>
#
# **Dependencies:** `numpy, conllu, datasets, transformers, seqeval`

# %% [markdown]
# ### Creating train-validation-test splits
# > Replace the file accordingly
#
# **Note: Skip this section if files are already available in form of train-val-test splits**

# %%
pip install conllu
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting conllu
#   Downloading conllu-4.5.2-py2.py3-none-any.whl (16 kB)
# Installing collected packages: conllu
# Successfully installed conllu-4.5.2

# %%
from conllu import parse

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_file = open("/content/drive/MyDrive/te_ud_train.conllu", "r", encoding="utf-8").read()
sentences = parse(data_file)
len(sentences)
print(sentences)
# Out:
# [TokenList<చూసేరా, అండీ, ?, metadata={sent_id: "1", text: "చూసేరా అండీ ?", translit: "cūserā aṁḍī ?"}>, TokenList<ఎక్కడికి, వెళ్తున్నారండీ, ?, metadata={sent_id: "2", text: "ఎక్కడికి వెళ్తున్నారండీ ?", translit: "èkkaḍiki vèḷtunnāraṁḍī ?"}>, TokenList<ఎప్పుడోయ్, అమెరికా, నించి, రావటం, ?, metadata={sent_id: "5", text: "ఎప్పుడోయ్ అమెరికా నించి రావటం ?", translit: "èppuḍoy amèrikā niṁci rāvaṭaṁ ?"}>, TokenList<ఎందుకయ్యా, ఈ, బాధ, ?, metadata={sent_id: "6", text: "ఎందుకయ్యా ఈ బాధ ?", translit: "èṁdukayyā ī bādha ?"}>, TokenList<ఇంటికి, పోరా, !, metadata={sent_id: "7", text: "ఇంటికి పోరా !", translit: "iṁṭiki porā !"}>, TokenList<పోయి, నీ, తాతతో, చెప్పరా, !, metadata={sent_id: "8", text: "పోయి నీ తాతతో చెప్పరా !", translit: "poyi nī tātato cèpparā !"}>, TokenList<బళ్ళు, సిద్ధం, చేయండిరా, !, metadata={sent_id: "9", text: "బళ్ళు సిద్ధం చేయండిరా !", translit: "baḷḷu siddhaṁ ceyaṁḍirā !"}>, TokenList<పోయి, మీ, పనులు, చేసుకోండిరా, !, metadata={sent_id: "10", text: "పోయి మీ పనులు చేసుకోండిరా !", translit: "poyi mī panulu cesukoṁḍirā !"}>, TokenList<అబద్దం, చెబుతానుటరా, ?, metadata={sent_id: "11", text: "అబద్దం చెబుతానుటరా ?", translit: "abaddaṁ cèbutānuṭarā ?"}>, TokenList<ఈ, రెండు, అక్షరాలు, దిద్దుకోవే, !, metadata={sent_id: "12", text: "ఈ రెండు అక్షరాలు దిద్దుకోవే !", translit: "ī rèṁḍu akṣarālu diddukove !"}>, TokenList<వాణ్ణి, కూడా, పిలవవే, !, metadata={sent_id: "13", text: "వాణ్ణి కూడా పిలవవే !", translit: "vāṇṇi kūḍā pilavave !"}>, TokenList<ఎక్కడ, ఉన్నావమ్మా, ఇప్పటిదాకా, ?, metadata={sent_id: "14", text: "ఎక్కడ ఉన్నావమ్మా ఇప్పటిదాకా ?", translit: "èkkaḍa unnāvammā ippaṭidākā ?"}>, TokenList<రాము, ఎల్లుండి, మద్రాసు, వెళ్తాడు, ., metadata={sent_id: "15", text: "రాము ఎల్లుండి మద్రాసు వెళ్తాడు .", translit: "rāmu èlluṁḍi madrāsu vèḷtāḍu ."}>, TokenList<రాము, రేపో, ఎల్లుండో, మద్రాసు, వెళ్తాడు, ., metadata={sent_id: "16", text: "రాము రేపో ఎల్లుండో మద్రాసు వెళ్తాడు .", translit: "rāmu repo èlluṁḍo madrāsu vèḷtāḍu ."}>, TokenList<రాము, రేపన్నా, ఎల్లుండన్నా, మద్రాసు, వెళ్తాడు, ., metadata={sent_id: "17", text: "రాము రేపన్నా ఎల్లుండన్నా మద్రాసు వెళ్తాడు .", translit: "rāmu repannā èlluṁḍannā madrāsu vèḷtāḍu ."}>, TokenList<మీరు, ఈ, పని, చెయ్యాలి, ., metadata={sent_id: "18", text: "మీరు ఈ పని చెయ్యాలి .", translit: "mīru ī pani cèyyāli ."}>, TokenList<నేను, ఈ, పని, చెయ్యాలి, ., metadata={sent_id: "19", text: "నేను ఈ పని చెయ్యాలి .", translit: "nenu ī pani cèyyāli ."}>, TokenList<మీరన్నా, నేనన్నా, ఈ, పని, చెయ్యాలి, ., metadata={sent_id: "21", text: "మీరన్నా నేనన్నా ఈ పని చెయ్యాలి .", translit: "mīrannā nenannā ī pani cèyyāli ."}>, TokenList<రాము, వస్తాడో, ,, రాడో, ., metadata={sent_id: "22", text: "రాము వస్తాడో , రాడో .", translit: "rāmu vastāḍo , rāḍo ."}>, TokenList<దేవుడు, ఉన్నాడో, ,, లేడో, ., metadata={sent_id: "23", text: "దేవుడు ఉన్నాడో , లేడో .", translit: "devuḍu unnāḍo , leḍo ."}>, TokenList<మళ్ళీ, నిన్ను, చూడగలనో, ,, లేదో, ., metadata={sent_id: "24", text: "మళ్ళీ నిన్ను చూడగలనో , లేదో .", translit: "maḷḷī ninnu cūḍagalano , ledo ."}>, TokenList<ఆమెకి, అప్పటికి, పదమూడు, సంవత్సరాలు, దాటేయో, లేదో, ,, గాని, అప్పటికే, బాగా, ఏపారిగా, ఉండేది, ., metadata={sent_id: "25", text: "ఆమెకి అప్పటికి పదమూడు సంవత్సరాలు దాటేయో లేదో , గాని అప్పటికే బాగా ఏపారిగా ఉండేది .", translit: "āmèki appaṭiki padamūḍu saṁvatsarālu dāṭeyo ledo , gāni appaṭike bāgā epārigā uṁḍedi ."}>, TokenList<అడవిలో, కాలు, పెట్టేనో, లేదో, ,, పెద్ద, పులి, కనబడింది, ., metadata={sent_id: "26", text: "అడవిలో కాలు పెట్టేనో లేదో , పెద్ద పులి కనబడింది .", translit: "aḍavilo kālu pèṭṭeno ledo , pèdda puli kanabaḍiṁdi ."}>, TokenList<తిలక్, మహాశయుడి, చావు, గురించి, జనం, మరిచేరో, లేదో, ,, గాంధీ, ముందుకు, వచ్చేరు, ., metadata={sent_id: "27", text: "తిలక్ మహాశయుడి చావు గురించి జనం మరిచేరో లేదో , గాంధీ ముందుకు వచ్చేరు .", translit: "tilak mahāśayuḍi cāvu guriṁci janaṁ maricero ledo , gāṁdhī muṁduku vacceru ."}>, TokenList<తరవాతి, పని, ఏమిటి, ?, metadata={sent_id: "28", text: "తరవాతి పని ఏమిటి ?", translit: "taravāti pani emiṭi ?"}>, TokenList<అతని, తరవాత, ఎవరు, ?, metadata={sent_id: "29", te ...

# %%
sentences = [sentence.serialize() for sentence in sentences]
print(sentences)
# Out:
# ['# sent_id = 1\n# text = చూసేరా అండీ ?\n# translit = cūserā aṁḍī ?\n1\tచూసేరా\t_\tVERB\tVERB\t_\t0\troot\t_\tTranslit=cūserā|LTranslit=_\n2\tఅండీ\t_\tPART\tPART\t_\t1\tdiscourse\t_\tTranslit=aṁḍī|LTranslit=_\n3\t?\t_\tPUNCT\tPUNCT\t_\t1\tpunct\t_\tTranslit=?|LTranslit=_\n\n', '# sent_id = 2\n# text = ఎక్కడికి వెళ్తున్నారండీ ?\n# translit = èkkaḍiki vèḷtunnāraṁḍī ?\n1\tఎక్కడికి\t_\tNOUN\tNOUN\t_\t2\tobl\t_\tTranslit=èkkaḍiki|LTranslit=_\n2\tవెళ్తున్నారండీ\t_\tVERB\tVERB\t_\t0\troot\t_\tTranslit=vèḷtunnāraṁḍī|LTranslit=_\n3\t?\t_\tPUNCT\tPUNCT\t_\t2\tpunct\t_\tTranslit=?|LTranslit=_\n\n', '# sent_id = 5\n# text = ఎప్పుడోయ్ అమెరికా నించి రావటం ?\n# translit = èppuḍoy amèrikā niṁci rāvaṭaṁ ?\n1\tఎప్పుడోయ్\t_\tPRON\tPRON\t_\t4\tobl:tmod\t_\tTranslit=èppuḍoy|LTranslit=_\n2\tఅమెరికా\t_\tPROPN\tPROPN\t_\t4\tobl\t_\tTranslit=amèrikā|LTranslit=_\n3\tనించి\t_\tADP\tADP\t_\t2\tcase\t_\tTranslit=niṁci|LTranslit=_\n4\tరావటం\t_\tVERB\tVERB\t_\t0\troot\t_\tTranslit=rāvaṭaṁ|LTranslit=_\n5\t?\t_\tPUNCT\tPUNCT\t_\t4\tpunct\t_\tTranslit=?|LTranslit=_\n\n', '# sent_id = 6\n# text = ఎందుకయ్యా ఈ బాధ ?\n# translit = èṁdukayyā ī bādha ?\n1\tఎందుకయ్యా\t_\tPRON\tPRON\t_\t3\tnsubj\t_\tTranslit=èṁdukayyā|LTranslit=_\n2\tఈ\t_\tDET\tDET\t_\t3\tdet\t_\tTranslit=ī|LTranslit=_\n3\tబాధ\t_\tNOUN\tNOUN\t_\t0\troot\t_\tTranslit=bādha|LTranslit=_\n4\t?\t_\tPUNCT\tPUNCT\t_\t3\tpunct\t_\tTranslit=?|LTranslit=_\n\n', '# sent_id = 7\n# text = ఇంటికి పోరా !\n# translit = iṁṭiki porā !\n1\tఇంటికి\t_\tNOUN\tNOUN\t_\t2\tobl\t_\tTranslit=iṁṭiki|LTranslit=_\n2\tపోరా\t_\tVERB\tVERB\t_\t0\troot\t_\tTranslit=porā|LTranslit=_\n3\t!\t_\tPUNCT\tPUNCT\t_\t2\tpunct\t_\tTranslit=!|LTranslit=_\n\n', '# sent_id = 8\n# text = పోయి నీ తాతతో చెప్పరా !\n# translit = poyi nī tātato cèpparā !\n1\tపోయి\t_\tVERB\tVERB\t_\t4\tadvcl\t_\tTranslit=poyi|LTranslit=_\n2\tనీ\t_\tPRON\tPRON\t_\t3\tnmod:poss\t_\tTranslit=nī|LTranslit=_\n3\tతాతతో\t_\tNOUN\tNOUN\t_\t4\tobl\t_\tTranslit=tātato|LTranslit=_\n4\tచెప్పరా\t_\tVERB\tVERB\t_\t0\troot\t_\tTranslit=cèpparā|LTranslit=_\n5\t!\t_\tPUNCT\tPUNCT\t_\t4\tpunct\t_\tTranslit=!|LTranslit=_\n\n', '# sent_id = 9\n# text = బళ్ళు సిద్ధం చేయండిరా !\n# translit = baḷḷu siddhaṁ ceyaṁḍirā !\n1\tబళ్ళు\t_\tNOUN\tNOUN\t_\t3\tobj\t_\tTranslit=baḷḷu|LTranslit=_\n2\tసిద్ధం\t_\tVERB\tVERB\t_\t3\tcompound:svc\t_\tTranslit=siddhaṁ|LTranslit=_\n3\tచేయండిరా\t_\tVERB\tVERB\t_\t0\troot\t_\tTranslit=ceyaṁḍirā|LTranslit=_\n4\t!\t_\tPUNCT\tPUNCT\t_\t3\tpunct\t_\tTranslit=!|LTranslit=_\n\n', '# sent_id = 10\n# text = పోయి మీ పనులు చేసుకోండిరా !\n# translit = poyi mī panulu cesukoṁḍirā !\n1\tపోయి\t_\tVERB\tVERB\t_\t4\tadvcl\t_\tTranslit=poyi|LTranslit=_\n2\tమీ\t_\tPRON\tPRON\t_\t3\tnmod\t_\tTranslit=mī|LTranslit=_\n3\tపనులు\t_\tNOUN\tNOUN\t_\t4\tobj\t_\tTranslit=panulu|LTranslit=_\n4\tచేసుకోండిరా\t_\tVERB\tVERB\t_\t0\troot\t_\tTranslit=cesukoṁḍirā|LTranslit=_\n5\t!\t_\tPUNCT\tPUNCT\t_\t4\tpunct\t_\tTranslit=!|LTranslit=_\n\n', '# sent_id = 11\n# text = అబద్దం చెబుతానుటరా ?\n# translit = abaddaṁ cèbutānuṭarā ?\n1\tఅబద్దం\t_\tNOUN\tNOUN\t_\t2\tobj\t_\tTranslit=abaddaṁ|LTranslit=_\n2\tచెబుతానుటరా\t_\tVERB\tVERB\t_\t0\troot\t_\tTranslit=cèbutānuṭarā|LTranslit=_\n3\t?\t_\tPUNCT\tPUNCT\t_\t2\tpunct\t_\tTranslit=?|LTranslit=_\n\n', '# sent_id = 12\n# text = ఈ రెండు అక్షరాలు దిద్దుకోవే !\n# translit = ī rèṁḍu akṣarālu diddukove !\n1\tఈ\t_\tDET\tDET\t_\t3\tdet\t_\tTranslit=ī|LTranslit=_\n2\tరెండు\t_\tNUM\tNUM\tNumType=Card\t3\tnummod\t_\tTranslit=rèṁḍu|LTranslit=_\n3\tఅక్షరాలు\t_\tNOUN\tNOUN\t_\t4\tobj\t_\tTranslit=akṣarālu|LTranslit=_\n4\tదిద్దుకోవే\t_\tVERB\tVERB\t_\t0\troot\t_\tTranslit=diddukove|LTranslit=_\n5\t!\t_\tPUNCT\tPUNCT\t_\t4\tpunct\t_\tTranslit=!|LTranslit=_\n\n', '# sent_id = 13\n# text = వాణ్ణి కూడా పిలవవే !\n# translit = vāṇṇi kūḍā pilavave !\n1\tవాణ్ణి\t_\tPRON\tPRON\t_\t3\tobj\t_\tTranslit=vāṇṇi|LTranslit=_\n2\tకూడా\t_\tADP\tADP\t_\t1\tcase\t_\tTranslit=kūḍā|LTranslit=_\n3\tపిలవవే\t_\tVERB\tVERB\t_\t0\troot\t_\tTranslit=pilavave|LTranslit=_\n4\t!\t_\tPUNCT\tPUNCT\t_\t3\tp ...

# %%
from sklearn.model_selection import train_test_split

## Split size may be adjusted here
train, test = train_test_split(sentences,test_size=0.20)
train, val = train_test_split(train,test_size=0.10)

# %%
len(train),len(val),len(test)
# Out:
# (756, 84, 211)

# %% [markdown]
# > Storing the outputs in `data/` folder

# %%
import os

## Create directory data/ if does not exist
if not os.path.exists('data'):
    os.makedirs('data')
    
for l,s in zip([train,val,test],['train','validation','test']):
    with open(f'data/{s}.conllu','w',encoding='utf-8') as fp:
        fp.write(''.join(l))

# %% [markdown]
# ### Tokenization
#
# The following section does tokenization for UPOS tagging task

# %% [markdown]
# > Loading data

# %%
pip install datasets
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting datasets
#   Downloading datasets-2.6.1-py3-none-any.whl (441 kB)
#      |████████████████████████████████| 441 kB 4.4 MB/s
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (2.23.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from datasets) (1.21.6)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from datasets) (4.13.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.7/dist-packages (from datasets) (4.64.1)
# Collecting huggingface-hub<1.0.0,>=0.2.0
#   Downloading huggingface_hub-0.10.1-py3-none-any.whl (163 kB)
#      |████████████████████████████████| 163 kB 45.1 MB/s
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.7/dist-packages (from datasets) (2022.10.0)
# Collecting dill<0.3.6
#   Downloading dill-0.3.5.1-py2.py3-none-any.whl (95 kB)
#      |████████████████████████████████| 95 kB 5.1 MB/s
# Collecting xxhash
#   Downloading xxhash-3.1.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      |████████████████████████████████| 212 kB 47.4 MB/s
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets) (1.3.5)
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py37-none-any.whl (115 kB)
#      |████████████████████████████████| 115 kB 41.0 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from datasets) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from datasets) (6.0)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from datasets) (3.8.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (22.1.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (0.13.0)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (4.1.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (6.0.2)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (2.1.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.8.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets) (3.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->datasets) (3.0.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2022.9.24)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (1.24.3)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 46.3 MB/s
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->datasets) (3.10.0)
# Collecting multiprocess
#   Downloading multiprocess-0.70.13-py37-none-any.whl (115 kB)
#      |████████████████████████████████| 115 kB 47.7 MB/s
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2022.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.15.0)
# Installing collected packages: urllib3, dill, xxhash, responses, multiprocess, huggingface-hub, datasets
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: dill
#     Found existing installation: dill 0.3.6
#     Uninstalling dill-0.3.6:
#       Successfully uninstalled dill-0.3.6
# Successfully installed datasets-2.6.1 dill-0.3.5.1 huggingface-hub-0.10.1 multiprocess-0.70.13 responses-0.18.0 urllib3-1.25.11 xxhash-3.1.0

# %%
from datasets import load_dataset

# %% [markdown]
# **Note: If the above convention for saving files was not followed, the file `ConlluIndic.py` needs to be editied so that `__TRAINING_FILE__` etc. point correctly**

# %%
dataset = load_dataset('/content/drive/MyDrive/ConlluIndic.py')
dataset
# print(path)
# Out:
# Downloading and preparing dataset conllu_indic/conlluindic to /root/.cache/huggingface/datasets/conllu_indic/conlluindic/1.0.0/50260ca812993370c93c5949d08ad1fb388e0fced25f584d6ede7b09423bc32c...
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# Dataset conllu_indic downloaded and prepared to /root/.cache/huggingface/datasets/conllu_indic/conlluindic/1.0.0/50260ca812993370c93c5949d08ad1fb388e0fced25f584d6ede7b09423bc32c. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'tokens', 'lemmas', 'upos_tags'],
#         num_rows: 756
#     })
#     validation: Dataset({
#         features: ['id', 'tokens', 'lemmas', 'upos_tags'],
#         num_rows: 84
#     })
#     test: Dataset({
#         features: ['id', 'tokens', 'lemmas', 'upos_tags'],
#         num_rows: 211
#     })
# })

# %% [markdown]
# > Tokenization

# %%
pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.24.0-py3-none-any.whl (5.5 MB)
#      |████████████████████████████████| 5.5 MB 4.0 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      |████████████████████████████████| 7.6 MB 29.8 MB/s
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.10.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.13.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.8.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.10.0->transformers) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.10.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2022.9.24)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Installing collected packages: tokenizers, transformers
# Successfully installed tokenizers-0.13.2 transformers-4.24.0

# %%
pip install sentencepiece
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.97-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 4.2 MB/s
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.97

# %%
from transformers import AutoTokenizer

model_checkpoint = 'ai4bharat/indic-bert'

tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)
# Out:
# Downloading:   0%|          | 0.00/507 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/5.65M [00:00<?, ?B/s]

# %%
def align_labels_with_tokens(labels, word_ids):
    new_labels = []
    current_word = None
    for word_id in word_ids:
        if word_id != current_word:
            # Start of a new word!
            current_word = word_id
            label = -100 if word_id is None else labels[word_id]
            new_labels.append(label)
        elif word_id is None:
            # Special token
            new_labels.append(-100)
        else:
            # Same word as previous token
            label = labels[word_id]
            # If the label is B-XXX we change it to I-XXX
            #if label % 2 == 1:
            #    label += 1
            new_labels.append(label)

    return new_labels

# %%
def tokenize_and_align_labels(examples):
    tokenized_inputs = tokenizer(
        examples["tokens"], truncation=True, is_split_into_words=True
    )
    all_labels = examples["upos_tags"]
    new_labels = []
    for i, labels in enumerate(all_labels):
        word_ids = tokenized_inputs.word_ids(i)
        new_labels.append(align_labels_with_tokens(labels, word_ids))

    tokenized_inputs["labels"] = new_labels
    return tokenized_inputs

# %%
tokenized_datasets = dataset.map(
    tokenize_and_align_labels,
    batched=True,
    remove_columns=dataset["train"].column_names,
)
# Out:
#   0%|          | 0/1 [00:00<?, ?ba/s]
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]

# %%
tokenized_datasets.save_to_disk('data/tokenized_datasets/')

# %% [markdown]
# ### Fine-tuning and Evaluation

# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification, DataCollatorForTokenClassification, TrainingArguments, Trainer
from datasets import load_metric, load_from_disk, load_dataset
import numpy as np

# %% [markdown]
# > Loads the model, tokenizer, data collator, metric and tokenized datasets
#
# **Note: Don't forget to edit the file paths if the previous conventions were not followed**

# %%
pip install seqeval
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting seqeval
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      |████████████████████████████████| 43 kB 1.4 MB/s
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.7/dist-packages (from seqeval) (1.21.6)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.7/dist-packages (from seqeval) (1.0.2)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.21.3->seqeval) (1.2.0)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.21.3->seqeval) (1.7.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.21.3->seqeval) (3.1.0)
# Building wheels for collected packages: seqeval
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16180 sha256=00346de8be0c304ef510d757b7d3acc655ee5d01ac29848549bd86a8d168ad24
#   Stored in directory: /root/.cache/pip/wheels/05/96/ee/7cac4e74f3b19e3158dce26a20a1c86b3533c43ec72a549fd7
# Successfully built seqeval
# Installing collected packages: seqeval
# Successfully installed seqeval-1.2.2

# %%
model_checkpoint = 'ai4bharat/indic-bert'


tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)
tokenized_datasets = load_from_disk('data/tokenized_datasets/')



data_collator = DataCollatorForTokenClassification(tokenizer=tokenizer)
metric = load_metric('seqeval')


dataset = load_dataset('/content/drive/MyDrive/ConlluIndic.py')

upos_feature = dataset['train'].features['upos_tags']
label_names = upos_feature.feature.names



id2label = {str(i): label for i, label in enumerate(label_names)}
label2id = {v: k for k, v in id2label.items()}


model = AutoModelForTokenClassification.from_pretrained(model_checkpoint,id2label=id2label,label2id=label2id)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
#   # Remove the CWD from sys.path while we load stuff.
# Downloading builder script:   0%|          | 0.00/2.47k [00:00<?, ?B/s]
# WARNING:datasets.builder:Found cached dataset conllu_indic (/root/.cache/huggingface/datasets/conllu_indic/conlluindic/1.0.0/50260ca812993370c93c5949d08ad1fb388e0fced25f584d6ede7b09423bc32c)
#   0%|          | 0/3 [00:00<?, ?it/s]
# Downloading:   0%|          | 0.00/135M [00:00<?, ?B/s]
# Some weights of the model checkpoint at ai4bharat/indic-bert were not used when initializing AlbertForTokenClassification: ['predictions.dense.bias', 'predictions.dense.weight', 'predictions.LayerNorm.weight', 'predictions.bias', 'predictions.decoder.bias', 'sop_classifier.classifier.weight', 'sop_classifier.classifier.bias', 'predictions.LayerNorm.bias', 'predictions.decoder.weight']
# - This IS expected if you are initializing AlbertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing AlbertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of AlbertForTokenClassification were not initialized from the model checkpoint at ai4bharat/indic-bert and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# > Metric computation

# %%
from seqeval.metrics import classification_report
lg =[]
lb=[]
predic=[]
tlb =[]
tpr=[]

# %%
def compute_metrics(eval_preds):
    logits, labels = eval_preds
    lg = logits
    lb = labels
    predictions = np.argmax(logits, axis=-1)
    predic = predictions

    # Remove ignored index (special tokens) and convert to labels
    true_labels = [[label_names[l] for l in label if l != -100] for label in labels]
    true_predictions = [
        [label_names[p] for (p, l) in zip(prediction, label) if l != -100]
        for prediction, label in zip(predictions, labels)
    ]

    tlb = true_labels
    tpr = true_predictions
    
    all_metrics = metric.compute(predictions=true_predictions, references=true_labels)
    print(all_metrics)
    classification_report(true_labels, true_predictions)
    return {
        "precision": all_metrics["overall_precision"],
        "recall": all_metrics["overall_recall"],
        "f1": all_metrics["overall_f1"],
        "accuracy": all_metrics["overall_accuracy"],
    }

# %% [markdown]
# > Defining the trainer
#
# `fp16 = True` may be set for GPU
#
# Similarly `batch_size` can be increased

# %%
batch_size = 14
args = TrainingArguments(
    output_dir=f"model/upos",
    overwrite_output_dir=True,
    evaluation_strategy="epoch",
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    save_strategy="epoch",
    learning_rate=2e-5,
    num_train_epochs=10,
    weight_decay=0.01,
    save_total_limit=1,
    # fp16= True,
)

trainer = Trainer(
    model=model,
    args=args,
    train_dataset=tokenized_datasets["train"],
    # eval_dataset=tokenized_datasets["validation"],
    eval_dataset=tokenized_datasets["test"],
    data_collator=data_collator,
    compute_metrics=compute_metrics,
    tokenizer=tokenizer,
)
# Out:
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %% [markdown]
# > Train the model

# %%
trainer.train()
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 756
#   Num Epochs = 10
#   Instantaneous batch size per device = 14
#   Total train batch size (w. parallel, distributed & accumulation) = 14
#   Gradient Accumulation steps = 1
#   Total optimization steps = 540
#   Number of trainable parameters = 32866834
#     <div>
#
#       <progress value='540' max='540' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [540/540 28:06, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.937453</td>
#       <td>0.671388</td>
#       <td>0.644022</td>
#       <td>0.657420</td>
#       <td>0.752983</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.759911</td>
#       <td>0.708092</td>
#       <td>0.665761</td>
#       <td>0.686275</td>
#       <td>0.784010</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>0.694121</td>
#       <td>0.743733</td>
#       <td>0.725543</td>
#       <td>0.734525</td>
#       <td>0.806683</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>No log</td>
#       <td>0.658835</td>
#       <td>0.746594</td>
#       <td>0.744565</td>
#       <td>0.745578</td>
#       <td>0.822196</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>No log</td>
#       <td>0.659856</td>
#       <td>0.784153</td>
#       <td>0.779891</td>
#       <td>0.782016</td>
#       <td>0.841289</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>No log</td>
#       <td>0.637136</td>
#       <td>0.755968</td>
#       <td>0.774457</td>
#       <td>0.765101</td>
#       <td>0.841289</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>No log</td>
#       <td>0.658403</td>
#       <td>0.797784</td>
#       <td>0.782609</td>
#       <td>0.790123</td>
#       <td>0.849642</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>No log</td>
#       <td>0.678158</td>
#       <td>0.797260</td>
#       <td>0.790761</td>
#       <td>0.793997</td>
#       <td>0.848449</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>No log</td>
#       <td>0.644172</td>
#       <td>0.788618</td>
#       <td>0.790761</td>
#       <td>0.789688</td>
#       <td>0.855609</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.484800</td>
#       <td>0.655620</td>
#       <td>0.797260</td>
#       <td>0.790761</td>
#       <td>0.793997</td>
#       <td>0.854415</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 84
#   Batch size = 14
# {'ART': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 1}, 'CONJ': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 8}, 'DJ': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 3}, 'DP': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 3}, 'DV': {'precision': 0.25, 'recall': 0.043478260869565216, 'f1': 0.07407407407407408, 'number': 23}, 'ERB': {'precision': 0.5851063829787234, 'recall': 0.7432432432432432, 'f1': 0.6547619047619048, 'number': 74}, 'ET': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 8}, 'NTJ': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 2}, 'OUN': {'precision': 0.48148148148148145, 'recall': 0.52, 'f1': 0.5, 'number': 75}, 'RON': {'precision': 0.5945945945945946, 'recall': 0.7719298245614035, 'f1': 0.6717557251908397, 'number': 57}, 'ROPN': {'precision': 0.8, 'recall': 0.4, 'f1': 0.5333333333333333, 'number': 20}, 'UM': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 4}, 'UNCT': {'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'number': 90}, 'overall_precision': 0.6713881019830028, 'overall_recall': 0.6440217391304348, 'overall_f1': 0.6574202496532593, 'overall_accuracy': 0.752983293556086}
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PROPN seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PRON seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: NOUN seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: VERB seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: SCONJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PUNCT seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: NUM seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADV seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: DET seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: INTJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADP seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PART seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to model/upos/checkpoint-54
# Configuration saved in model/upos/checkpoint-54/config.json
# Model weights saved in model/upos/checkpoint-54/pytorch_model.bin
# tokenizer config file saved in model/upos/checkpoint-54/tokenizer_config.json
# Special tokens file saved in model/upos/checkpoint-54/special_tokens_map.json
# Deleting older checkpoint [model/upos/checkpoint-255] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 84
#   Batch size = 14
# {'ART': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 1}, 'CONJ': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 8}, 'DJ': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 3}, 'DP': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 3}, 'DV': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 23}, 'ERB': {'precision': 0.7564102564102564, 'recall': 0.7972972972972973, 'f1': 0.7763157894736842, 'number': 74}, 'ET': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 8}, 'NTJ': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 2}, 'OUN': {'precision': 0.43157894736842106, 'recall': 0.5466666666666666, 'f1': 0.48235294117647054, 'number': 75}, 'RON': {'precision': 0.6521739130434783, 'recall': 0.7894736842105263, 'f1': 0.7142857142857143, 'number': 57}, 'ROPN': {'precision': 0.9090909090909091, 'recall': 0.5, 'f1': 0.6451612903225806, 'number': 20}, 'UM': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 4}, 'UNCT': {'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'number': 90}, 'overall_precision': 0.708092485549133, 'overall_recall': 0.6657608695652174, 'overall_f1': 0.6862745098039216, 'overall_accuracy': 0.7840095465393795}
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PROPN seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PRON seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: NOUN seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: VERB seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: SCONJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PUNCT seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: NUM seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADV seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: DET seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: INTJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADP seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PART seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to model/upos/checkpoint-108
# Configuration saved in model/upos/checkpoint-108/config.json
# Model weights saved in model/upos/checkpoint-108/pytorch_model.bin
# tokenizer config file saved in model/upos/checkpoint-108/tokenizer_config.json
# Special tokens file saved in model/upos/checkpoint-108/special_tokens_map.json
# Deleting older checkpoint [model/upos/checkpoint-54] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 84
#   Batch size = 14
# {'ART': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 1}, 'CONJ': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 8}, 'DJ': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 3}, 'DP': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 3}, 'DV': {'precision': 0.2, 'recall': 0.043478260869565216, 'f1': 0.07142857142857142, 'number': 23}, 'ERB': {'precision': 0.7294117647058823, 'recall': 0.8378378378378378, 'f1': 0.779874213836478, 'number': 74}, 'ET': {'precision': 1.0, 'recall': 0.5, 'f1': 0.6666666666666666, 'number': 8}, 'NTJ': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 2}, 'OUN': {'precision': 0.5, 'recall': 0.6133333333333333, 'f1': 0.5508982035928144, 'number': 75}, 'RON': {'precision': 0.7424242424242424, 'recall': 0.8596491228070176, 'f1': 0.7967479674796748, 'number': 57}, 'ROPN': {'precision': 0.8823529411764706, 'recall': 0.75, 'f1': 0.8108108108108107, 'number': 20}, 'UM': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 4}, 'UNCT': {'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'number': 90}, 'overall_precision': 0.7437325905292479, 'overall_recall': 0.7255434782608695, 'overall_f1': 0.734525447042641, 'overall_accuracy': 0.8066825775656324}
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PROPN seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PRON seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: NOUN seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: VERB seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: SCONJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PUNCT seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: NUM seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADV seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: DET seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: INTJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADP seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PART seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to model/upos/checkpoint-162
# Configuration saved in model/upos/checkpoint-162/config.json
# Model weights saved in model/upos/checkpoint-162/pytorch_model.bin
# tokenizer config file saved in model/upos/checkpoint-162/tokenizer_config.json
# Special tokens file saved in model/upos/checkpoint-162/special_tokens_map.json
# Deleting older checkpoint [model/upos/checkpoint-108] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 84
#   Batch size = 14
# {'ART': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 1}, 'CONJ': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 8}, 'DJ': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 3}, 'DP': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 3}, 'DV': {'precision': 0.2, 'recall': 0.13043478260869565, 'f1': 0.15789473684210528, 'number': 23}, 'ERB': {'precision': 0.7261904761904762, 'recall': 0.8243243243243243, 'f1': 0.7721518987341773, 'number': 74}, 'ET': {'precision': 1.0, 'recall': 0.625, 'f1': 0.7692307692307693, 'number': 8}, 'NTJ': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 2}, 'OUN': {'precision': 0.5632183908045977, 'recall': 0.6533333333333333, 'f1': 0.6049382716049383, 'number': 75}, 'RON': {'precision': 0.7647058823529411, 'recall': 0.9122807017543859, 'f1': 0.8319999999999999, 'number': 57}, 'ROPN': {'precision': 0.7777777777777778, 'recall': 0.7, 'f1': 0.7368421052631577, 'number': 20}, 'UM': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 4}, 'UNCT': {'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'number': 90}, 'overall_precision': 0.7465940054495913, 'overall_recall': 0.7445652173913043, 'overall_f1': 0.745578231292517, 'overall_accuracy': 0.8221957040572793}
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PROPN seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PRON seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: NOUN seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: VERB seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: SCONJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PUNCT seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: NUM seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADV seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: DET seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: INTJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADP seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PART seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to model/upos/checkpoint-216
# Configuration saved in model/upos/checkpoint-216/config.json
# Model weights saved in model/upos/checkpoint-216/pytorch_model.bin
# tokenizer config file saved in model/upos/checkpoint-216/tokenizer_config.json
# Special tokens file saved in model/upos/checkpoint-216/special_tokens_map.json
# Deleting older checkpoint [model/upos/checkpoint-162] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 84
#   Batch size = 14
# {'ART': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 1}, 'CONJ': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 8}, 'DJ': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 3}, 'DP': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 3}, 'DV': {'precision': 0.45454545454545453, 'recall': 0.43478260869565216, 'f1': 0.4444444444444445, 'number': 23}, 'ERB': {'precision': 0.7558139534883721, 'recall': 0.8783783783783784, 'f1': 0.8125, 'number': 74}, 'ET': {'precision': 1.0, 'recall': 0.625, 'f1': 0.7692307692307693, 'number': 8}, 'NTJ': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 2}, 'OUN': {'precision': 0.6712328767123288, 'recall': 0.6533333333333333, 'f1': 0.6621621621621622, 'number': 75}, 'RON': {'precision': 0.7142857142857143, 'recall': 0.8771929824561403, 'f1': 0.7874015748031495, 'number': 57}, 'ROPN': {'precision': 0.8888888888888888, 'recall': 0.8, 'f1': 0.8421052631578948, 'number': 20}, 'UM': {'precision': 1.0, 'recall': 0.5, 'f1': 0.6666666666666666, 'number': 4}, 'UNCT': {'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'number': 90}, 'overall_precision': 0.7841530054644809, 'overall_recall': 0.779891304347826, 'overall_f1': 0.782016348773842, 'overall_accuracy': 0.8412887828162291}
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PROPN seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PRON seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: NOUN seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: VERB seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: SCONJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PUNCT seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: NUM seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADV seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: DET seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: INTJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADP seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PART seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to model/upos/checkpoint-270
# Configuration saved in model/upos/checkpoint-270/config.json
# Model weights saved in model/upos/checkpoint-270/pytorch_model.bin
# tokenizer config file saved in model/upos/checkpoint-270/tokenizer_config.json
# Special tokens file saved in model/upos/checkpoint-270/special_tokens_map.json
# Deleting older checkpoint [model/upos/checkpoint-216] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 84
#   Batch size = 14
# {'ART': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 1}, 'CONJ': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 8}, 'DJ': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 3}, 'DP': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 3}, 'DV': {'precision': 0.34782608695652173, 'recall': 0.34782608695652173, 'f1': 0.34782608695652173, 'number': 23}, 'ERB': {'precision': 0.6976744186046512, 'recall': 0.8108108108108109, 'f1': 0.75, 'number': 74}, 'ET': {'precision': 1.0, 'recall': 0.625, 'f1': 0.7692307692307693, 'number': 8}, 'NTJ': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 2}, 'OUN': {'precision': 0.611764705882353, 'recall': 0.6933333333333334, 'f1': 0.65, 'number': 75}, 'RON': {'precision': 0.7352941176470589, 'recall': 0.8771929824561403, 'f1': 0.8, 'number': 57}, 'ROPN': {'precision': 1.0, 'recall': 0.9, 'f1': 0.9473684210526316, 'number': 20}, 'UM': {'precision': 1.0, 'recall': 0.5, 'f1': 0.6666666666666666, 'number': 4}, 'UNCT': {'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'number': 90}, 'overall_precision': 0.7559681697612732, 'overall_recall': 0.7744565217391305, 'overall_f1': 0.7651006711409397, 'overall_accuracy': 0.8412887828162291}
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PROPN seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PRON seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: NOUN seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: VERB seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: SCONJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PUNCT seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: NUM seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADV seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: DET seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: INTJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADP seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PART seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to model/upos/checkpoint-324
# Configuration saved in model/upos/checkpoint-324/config.json
# Model weights saved in model/upos/checkpoint-324/pytorch_model.bin
# tokenizer config file saved in model/upos/checkpoint-324/tokenizer_config.json
# Special tokens file saved in model/upos/checkpoint-324/special_tokens_map.json
# Deleting older checkpoint [model/upos/checkpoint-270] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 84
#   Batch size = 14
# {'ART': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 1}, 'CONJ': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 8}, 'DJ': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 3}, 'DP': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 3}, 'DV': {'precision': 0.42105263157894735, 'recall': 0.34782608695652173, 'f1': 0.380952380952381, 'number': 23}, 'ERB': {'precision': 0.7380952380952381, 'recall': 0.8378378378378378, 'f1': 0.7848101265822786, 'number': 74}, 'ET': {'precision': 1.0, 'recall': 0.625, 'f1': 0.7692307692307693, 'number': 8}, 'NTJ': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 2}, 'OUN': {'precision': 0.6973684210526315, 'recall': 0.7066666666666667, 'f1': 0.7019867549668874, 'number': 75}, 'RON': {'precision': 0.746268656716418, 'recall': 0.8771929824561403, 'f1': 0.8064516129032258, 'number': 57}, 'ROPN': {'precision': 1.0, 'recall': 0.9, 'f1': 0.9473684210526316, 'number': 20}, 'UM': {'precision': 1.0, 'recall': 0.5, 'f1': 0.6666666666666666, 'number': 4}, 'UNCT': {'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'number': 90}, 'overall_precision': 0.7977839335180056, 'overall_recall': 0.782608695652174, 'overall_f1': 0.7901234567901234, 'overall_accuracy': 0.8496420047732697}
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PROPN seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PRON seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: NOUN seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: VERB seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: SCONJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PUNCT seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: NUM seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADV seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: DET seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: INTJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADP seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PART seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to model/upos/checkpoint-378
# Configuration saved in model/upos/checkpoint-378/config.json
# Model weights saved in model/upos/checkpoint-378/pytorch_model.bin
# tokenizer config file saved in model/upos/checkpoint-378/tokenizer_config.json
# Special tokens file saved in model/upos/checkpoint-378/special_tokens_map.json
# Deleting older checkpoint [model/upos/checkpoint-324] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 84
#   Batch size = 14
# {'ART': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 1}, 'CONJ': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 8}, 'DJ': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 3}, 'DP': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 3}, 'DV': {'precision': 0.42105263157894735, 'recall': 0.34782608695652173, 'f1': 0.380952380952381, 'number': 23}, 'ERB': {'precision': 0.7126436781609196, 'recall': 0.8378378378378378, 'f1': 0.7701863354037266, 'number': 74}, 'ET': {'precision': 1.0, 'recall': 0.625, 'f1': 0.7692307692307693, 'number': 8}, 'NTJ': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 2}, 'OUN': {'precision': 0.6923076923076923, 'recall': 0.72, 'f1': 0.7058823529411765, 'number': 75}, 'RON': {'precision': 0.7878787878787878, 'recall': 0.9122807017543859, 'f1': 0.8455284552845528, 'number': 57}, 'ROPN': {'precision': 1.0, 'recall': 0.9, 'f1': 0.9473684210526316, 'number': 20}, 'UM': {'precision': 1.0, 'recall': 0.5, 'f1': 0.6666666666666666, 'number': 4}, 'UNCT': {'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'number': 90}, 'overall_precision': 0.7972602739726027, 'overall_recall': 0.7907608695652174, 'overall_f1': 0.7939972714870396, 'overall_accuracy': 0.8484486873508353}
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PROPN seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PRON seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: NOUN seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: VERB seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: SCONJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PUNCT seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: NUM seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADV seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: DET seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: INTJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADP seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PART seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to model/upos/checkpoint-432
# Configuration saved in model/upos/checkpoint-432/config.json
# Model weights saved in model/upos/checkpoint-432/pytorch_model.bin
# tokenizer config file saved in model/upos/checkpoint-432/tokenizer_config.json
# Special tokens file saved in model/upos/checkpoint-432/special_tokens_map.json
# Deleting older checkpoint [model/upos/checkpoint-378] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 84
#   Batch size = 14
# {'ART': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 1}, 'CONJ': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 8}, 'DJ': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 3}, 'DP': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 3}, 'DV': {'precision': 0.5238095238095238, 'recall': 0.4782608695652174, 'f1': 0.5, 'number': 23}, 'ERB': {'precision': 0.7011494252873564, 'recall': 0.8243243243243243, 'f1': 0.7577639751552796, 'number': 74}, 'ET': {'precision': 1.0, 'recall': 0.625, 'f1': 0.7692307692307693, 'number': 8}, 'NTJ': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 2}, 'OUN': {'precision': 0.6708860759493671, 'recall': 0.7066666666666667, 'f1': 0.6883116883116883, 'number': 75}, 'RON': {'precision': 0.7727272727272727, 'recall': 0.8947368421052632, 'f1': 0.8292682926829269, 'number': 57}, 'ROPN': {'precision': 1.0, 'recall': 0.9, 'f1': 0.9473684210526316, 'number': 20}, 'UM': {'precision': 1.0, 'recall': 0.5, 'f1': 0.6666666666666666, 'number': 4}, 'UNCT': {'precision': 0.989010989010989, 'recall': 1.0, 'f1': 0.994475138121547, 'number': 90}, 'overall_precision': 0.7886178861788617, 'overall_recall': 0.7907608695652174, 'overall_f1': 0.7896879240162823, 'overall_accuracy': 0.8556085918854416}
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PROPN seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PRON seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: NOUN seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: VERB seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: SCONJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PUNCT seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: NUM seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADV seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: DET seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: INTJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADP seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PART seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to model/upos/checkpoint-486
# Configuration saved in model/upos/checkpoint-486/config.json
# Model weights saved in model/upos/checkpoint-486/pytorch_model.bin
# tokenizer config file saved in model/upos/checkpoint-486/tokenizer_config.json
# Special tokens file saved in model/upos/checkpoint-486/special_tokens_map.json
# Deleting older checkpoint [model/upos/checkpoint-432] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 84
#   Batch size = 14
# {'ART': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 1}, 'CONJ': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 8}, 'DJ': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 3}, 'DP': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 3}, 'DV': {'precision': 0.55, 'recall': 0.4782608695652174, 'f1': 0.5116279069767442, 'number': 23}, 'ERB': {'precision': 0.7011494252873564, 'recall': 0.8243243243243243, 'f1': 0.7577639751552796, 'number': 74}, 'ET': {'precision': 1.0, 'recall': 0.625, 'f1': 0.7692307692307693, 'number': 8}, 'NTJ': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 2}, 'OUN': {'precision': 0.72, 'recall': 0.72, 'f1': 0.72, 'number': 75}, 'RON': {'precision': 0.746268656716418, 'recall': 0.8771929824561403, 'f1': 0.8064516129032258, 'number': 57}, 'ROPN': {'precision': 1.0, 'recall': 0.9, 'f1': 0.9473684210526316, 'number': 20}, 'UM': {'precision': 1.0, 'recall': 0.5, 'f1': 0.6666666666666666, 'number': 4}, 'UNCT': {'precision': 0.989010989010989, 'recall': 1.0, 'f1': 0.994475138121547, 'number': 90}, 'overall_precision': 0.7972602739726027, 'overall_recall': 0.7907608695652174, 'overall_f1': 0.7939972714870396, 'overall_accuracy': 0.8544152744630071}
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PROPN seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PRON seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: NOUN seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: VERB seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: SCONJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PUNCT seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: NUM seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADV seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: DET seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: INTJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADP seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PART seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to model/upos/checkpoint-540
# Configuration saved in model/upos/checkpoint-540/config.json
# Model weights saved in model/upos/checkpoint-540/pytorch_model.bin
# tokenizer config file saved in model/upos/checkpoint-540/tokenizer_config.json
# Special tokens file saved in model/upos/checkpoint-540/special_tokens_map.json
# Deleting older checkpoint [model/upos/checkpoint-486] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=540, training_loss=0.46985576770923754, metrics={'train_runtime': 1689.5227, 'train_samples_per_second': 4.475, 'train_steps_per_second': 0.32, 'total_flos': 6437213072976.0, 'train_loss': 0.46985576770923754, 'epoch': 10.0})

# %% [markdown]
# > Evaluate the model
#
# **Note: Make sure evaluation results are reported on test dataset, for this training args should be changed**

# %%
results_eval = trainer.evaluate()
# Out:
# ***** Running Evaluation *****
#   Num examples = 84
#   Batch size = 14
#     <div>
#
#       <progress value='6' max='6' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [6/6 00:04]
#     </div>
# {'ART': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 1}, 'CONJ': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 8}, 'DJ': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 3}, 'DP': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 3}, 'DV': {'precision': 0.55, 'recall': 0.4782608695652174, 'f1': 0.5116279069767442, 'number': 23}, 'ERB': {'precision': 0.7011494252873564, 'recall': 0.8243243243243243, 'f1': 0.7577639751552796, 'number': 74}, 'ET': {'precision': 1.0, 'recall': 0.625, 'f1': 0.7692307692307693, 'number': 8}, 'NTJ': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 2}, 'OUN': {'precision': 0.72, 'recall': 0.72, 'f1': 0.72, 'number': 75}, 'RON': {'precision': 0.746268656716418, 'recall': 0.8771929824561403, 'f1': 0.8064516129032258, 'number': 57}, 'ROPN': {'precision': 1.0, 'recall': 0.9, 'f1': 0.9473684210526316, 'number': 20}, 'UM': {'precision': 1.0, 'recall': 0.5, 'f1': 0.6666666666666666, 'number': 4}, 'UNCT': {'precision': 0.989010989010989, 'recall': 1.0, 'f1': 0.994475138121547, 'number': 90}, 'overall_precision': 0.7972602739726027, 'overall_recall': 0.7907608695652174, 'overall_f1': 0.7939972714870396, 'overall_accuracy': 0.8544152744630071}
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PROPN seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PRON seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: NOUN seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: VERB seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: SCONJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PUNCT seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: NUM seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADV seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: DET seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: INTJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADP seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PART seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
results_test = trainer.evaluate()
# Out:
# ***** Running Evaluation *****
#   Num examples = 211
#   Batch size = 14
#     <div>
#
#       <progress value='16' max='16' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [16/16 00:13]
#     </div>
# {'ART': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 5}, 'CONJ': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 13}, 'DJ': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 10}, 'DP': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 10}, 'DV': {'precision': 0.42, 'recall': 0.5121951219512195, 'f1': 0.46153846153846156, 'number': 41}, 'ERB': {'precision': 0.73, 'recall': 0.7192118226600985, 'f1': 0.7245657568238213, 'number': 203}, 'ET': {'precision': 0.8, 'recall': 0.6896551724137931, 'f1': 0.7407407407407408, 'number': 29}, 'NTJ': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 3}, 'OUN': {'precision': 0.6032608695652174, 'recall': 0.6032608695652174, 'f1': 0.6032608695652174, 'number': 184}, 'RON': {'precision': 0.7547169811320755, 'recall': 0.8, 'f1': 0.7766990291262137, 'number': 150}, 'ROPN': {'precision': 0.8, 'recall': 0.8, 'f1': 0.8000000000000002, 'number': 35}, 'UM': {'precision': 0.5, 'recall': 0.08333333333333333, 'f1': 0.14285714285714285, 'number': 12}, 'UNCT': {'precision': 0.9957264957264957, 'recall': 1.0, 'f1': 0.9978586723768736, 'number': 233}, 'overall_precision': 0.7649043869516311, 'overall_recall': 0.7327586206896551, 'overall_f1': 0.7484865162355532, 'overall_accuracy': 0.8263443512580168}
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PRON seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: NOUN seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: VERB seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PUNCT seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: DET seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PROPN seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADV seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: SCONJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: NUM seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADP seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: INTJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PART seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: CCONJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
print("Micro Precision: ",(results_eval["eval_precision"]))
print("Micro Recall: ",(results_eval["eval_recall"]))
print("Micro F-Score: ",(results_eval["eval_f1"]))
print("Macro Precision: ",(results_eval["eval_precision"]+results_test["eval_precision"])/2)
print("Macro Recall: ",(results_eval["eval_recall"]+results_test["eval_recall"])/2)
print("Macro F-Score: ",(results_eval["eval_f1"]+results_test["eval_f1"])/2)
# Out:
# Micro Precision:  0.7972602739726027
# Micro Recall:  0.7907608695652174
# Micro F-Score:  0.7939972714870396
# Macro Precision:  0.7810823304621168
# Macro Recall:  0.7617597451274363
# Macro F-Score:  0.7712418938612964
